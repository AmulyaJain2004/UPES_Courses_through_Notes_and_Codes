# %%
import ml_utils as mt 
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor,plot_tree
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,ExtraTreesClassifier,ExtraTreesRegressor
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt 
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Regression Trees

# %%
ld_train=pd.read_csv('loan_data_train.csv')
def custom_dir(dir_col):
    
    temp=dir_col.str.replace('%','')
    num=pd.to_numeric(temp,errors='coerce')
    
    return num

def custom_fico(fico_col):
    
    temp=fico_col.str.split('-',expand=True)
    for i in [0,1]:
        temp[i]=pd.to_numeric(temp[i],errors='coerce')
    num=0.5*(temp[0]+temp[1])
    
    return num

def custom_el(el_col):
    temp=el_col.replace({'5 years':5, '4 years':4, '< 1 year':0, 
           '10+ years':10, '2 years':2,'8 years':8, 
           '1 year':1, '6 years':6, '7 years':7, 
           '3 years':3, '9 years':9})
    num=pd.to_numeric(temp,errors='coerce')
    return num

cat_to_num_cols=['Amount.Requested',
                'Open.CREDIT.Lines','Revolving.CREDIT.Balance']
simple_num_cols=['Monthly.Income','Inquiries.in.the.Last.6.Months']
cat_to_dummies_cols=[ 'Loan.Length','Loan.Purpose',
                    'State','Home.Ownership']
custom_func_cols={'Debt.To.Income.Ratio':custom_dir,
                    'FICO.Range':custom_fico,
                    'Employment.Length':custom_el}
ld_pipe=mt.DataPipe(simple_num=simple_num_cols,
                   cat_to_num=cat_to_num_cols,
                   cat_to_dummies=cat_to_dummies_cols,
                   custom_func_dict=custom_func_cols)
ld_pipe.fit(ld_train)
x_train=ld_pipe.transform(ld_train)
y_train=ld_train['Interest.Rate'].str.replace('%','').astype(float)
# Out:
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=pd.to_numeric(x[col],errors='coerce')
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=pd.to_numeric(x[col],errors='coerce')
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])

# %%
params={
        'max_depth':[None,5,6,7,8,10,15,20,30,50], # 10
        'min_samples_leaf':[1,2,5,10,15,20], # 6
        'min_samples_split':[2,5,10,15,20] # 5
        }

# %%
reg=DecisionTreeRegressor()

# %%
rs=RandomizedSearchCV(reg,
                     cv=10,
                     param_distributions=params,
                     scoring='neg_mean_absolute_error',
                     n_iter=50,
                     n_jobs=-1,
                     verbose=20)

# %%
rs.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# RandomizedSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [None, 5, 6, 7, 8, 10, 15,
#                                                       20, 30, 50],
#                                         'min_samples_leaf': [1, 2, 5, 10, 15,
#                                                              20],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               20]},
#                    scoring='neg_mean_absolute_error', verbose=20)

# %%
mt.report(rs.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: -1.469298 (std: 0.106597)
# Parameters: {'min_samples_split': 5, 'min_samples_leaf': 15, 'max_depth': 7}
#
# Model with rank: 2
# Mean validation score: -1.473585 (std: 0.104669)
# Parameters: {'min_samples_split': 15, 'min_samples_leaf': 15, 'max_depth': 8}
#
# Model with rank: 3
# Mean validation score: -1.481331 (std: 0.128994)
# Parameters: {'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 7}
#
# Model with rank: 4
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 20}
#
# Model with rank: 4
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 50}
#
# Model with rank: 4
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 50}
#
# Model with rank: 4
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15}

# %%
dt=DecisionTreeRegressor(**{'min_samples_split': 5, 'min_samples_leaf': 15, 'max_depth': 8})

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=15, min_samples_split=5)

# %%
from sklearn.tree import export_graphviz
import graphviz

# Generate DOT data
dot_data = export_graphviz(
    dt,
    out_file=None,  # No file output, just return as a string
    feature_names=x_train.columns,
    class_names=["0", "1"],
    filled=True,
    rounded=True,
    special_characters=True
)

# Render with Graphviz
graph = graphviz.Source(dot_data)
graph.render("decision_tree", format="png", cleanup=True)  # Saves as a high-quality PNG
graph  # Display in Jupyter Notebook (if applicable)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 2
#       1 from sklearn.tree import export_graphviz
# ----> 2 import graphviz
#       4 # Generate DOT data
#       5 dot_data = export_graphviz(
#       6     dt,
#       7     out_file=None,  # No file output, just return as a string
#    (...)
#      12     special_characters=True
#      13 )
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
from sklearn.tree import export_text

tree_rules = export_text(dt, feature_names=x_train.columns)
print(tree_rules)
# Out:
# |--- FICO.Range <= 704.50
# |   |--- Loan.Length_60 months <= 0.50
# |   |   |--- FICO.Range <= 679.50
# |   |   |   |--- Amount.Requested <= 13062.50
# |   |   |   |   |--- FICO.Range <= 669.50
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6037.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 22.72
# |   |   |   |   |   |   |   |   |--- value: [15.15]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  22.72
# |   |   |   |   |   |   |   |   |--- value: [16.71]
# |   |   |   |   |   |   |--- Amount.Requested >  6037.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 11.07
# |   |   |   |   |   |   |   |   |--- value: [15.42]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  11.07
# |   |   |   |   |   |   |   |   |--- value: [17.15]
# |   |   |   |   |--- FICO.Range >  669.50
# |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 6500.00
# |   |   |   |   |   |   |   |   |--- value: [13.89]
# |   |   |   |   |   |   |   |--- Amount.Requested >  6500.00
# |   |   |   |   |   |   |   |   |--- value: [15.03]
# |   |   |   |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 13.57
# |   |   |   |   |   |   |   |   |--- value: [12.90]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  13.57
# |   |   |   |   |   |   |   |   |--- value: [13.98]
# |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6862.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 3708.33
# |   |   |   |   |   |   |   |   |--- value: [14.26]
# |   |   |   |   |   |   |   |--- Monthly.Income >  3708.33
# |   |   |   |   |   |   |   |   |--- value: [15.23]
# |   |   |   |   |   |   |--- Amount.Requested >  6862.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 5735.04
# |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |--- Monthly.Income >  5735.04
# |   |   |   |   |   |   |   |   |--- value: [15.02]
# |   |   |   |--- Amount.Requested >  13062.50
# |   |   |   |   |--- FICO.Range <= 669.50
# |   |   |   |   |   |--- Amount.Requested <= 18575.00
# |   |   |   |   |   |   |--- value: [18.11]
# |   |   |   |   |   |--- Amount.Requested >  18575.00
# |   |   |   |   |   |   |--- value: [19.87]
# |   |   |   |   |--- FICO.Range >  669.50
# |   |   |   |   |   |--- Amount.Requested <= 18112.50
# |   |   |   |   |   |   |--- value: [16.26]
# |   |   |   |   |   |--- Amount.Requested >  18112.50
# |   |   |   |   |   |   |--- value: [18.01]
# |   |   |--- FICO.Range >  679.50
# |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |--- Amount.Requested <= 22950.00
# |   |   |   |   |   |--- Amount.Requested <= 7350.00
# |   |   |   |   |   |   |--- FICO.Range <= 694.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [12.78]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  7.50
# |   |   |   |   |   |   |   |   |--- value: [11.74]
# |   |   |   |   |   |   |--- FICO.Range >  694.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 15.62
# |   |   |   |   |   |   |   |   |--- value: [11.15]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  15.62
# |   |   |   |   |   |   |   |   |--- value: [9.78]
# |   |   |   |   |   |--- Amount.Requested >  7350.00
# |   |   |   |   |   |   |--- FICO.Range <= 699.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [14.41]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  6.50
# |   |   |   |   |   |   |   |   |--- value: [12.78]
# |   |   |   |   |   |   |--- FICO.Range >  699.50
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 11251.50
# |   |   |   |   |   |   |   |   |--- value: [11.24]
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  11251.50
# |   |   |   |   |   |   |   |   |--- value: [11.99]
# |   |   |   |   |--- Amount.Requested >  22950.00
# |   |   |   |   |   |--- value: [15.84]
# |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |--- Amount.Requested <= 16037.50
# |   |   |   |   |   |--- FICO.Range <= 684.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6750.00
# |   |   |   |   |   |   |   |--- value: [13.79]
# |   |   |   |   |   |   |--- Amount.Requested >  6750.00
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 19.06
# |   |   |   |   |   |   |   |   |--- value: [14.90]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  19.06
# |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |--- FICO.Range >  684.50
# |   |   |   |   |   |   |--- Home.Ownership_MORTGAGE <= 0.50
# |   |   |   |   |   |   |   |--- Loan.Purpose_debt_consolidation <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [14.11]
# |   |   |   |   |   |   |   |--- Loan.Purpose_debt_consolidation >  0.50
# |   |   |   |   |   |   |   |   |--- value: [13.27]
# |   |   |   |   |   |   |--- Home.Ownership_MORTGAGE >  0.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 9700.00
# |   |   |   |   |   |   |   |   |--- value: [12.56]
# |   |   |   |   |   |   |   |--- Amount.Requested >  9700.00
# |   |   |   |   |   |   |   |   |--- value: [13.48]
# |   |   |   |   |--- Amount.Requested >  16037.50
# |   |   |   |   |   |--- Debt.To.Income.Ratio <= 18.03
# |   |   |   |   |   |   |--- value: [15.50]
# |   |   |   |   |   |--- Debt.To.Income.Ratio >  18.03
# |   |   |   |   |   |   |--- value: [16.61]
# |   |--- Loan.Length_60 months >  0.50
# |   |   |--- Amount.Requested <= 16325.00
# |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |--- Revolving.CREDIT.Balance <= 7840.00
# |   |   |   |   |   |--- value: [18.60]
# |   |   |   |   |--- Revolving.CREDIT.Balance >  7840.00
# |   |   |   |   |   |--- value: [20.09]
# |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |--- FICO.Range <= 699.50
# |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 10940.00
# |   |   |   |   |   |   |--- Amount.Requested <= 8525.00
# |   |   |   |   |   |   |   |--- value: [15.90]
# |   |   |   |   |   |   |--- Amount.Requested >  8525.00
# |   |   |   |   |   |   |   |--- value: [16.74]
# |   |   |   |   |   |--- Revolving.CREDIT.Balance >  10940.00
# |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |--- FICO.Range >  699.50
# |   |   |   |   |   |--- value: [15.05]
# |   |   |--- Amount.Requested >  16325.00
# |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |--- Employment.Length <= 7.50
# |   |   |   |   |   |--- value: [22.09]
# |   |   |   |   |--- Employment.Length >  7.50
# |   |   |   |   |   |--- value: [22.88]
# |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |--- Amount.Requested <= 27750.00
# |   |   |   |   |   |--- FICO.Range <= 694.50
# |   |   |   |   |   |   |--- Amount.Requested <= 20875.00
# |   |   |   |   |   |   |   |--- value: [18.83]
# |   |   |   |   |   |   |--- Amount.Requested >  20875.00
# |   |   |   |   |   |   |   |--- value: [19.87]
# |   |   |   |   |   |--- FICO.Range >  694.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- Amount.Requested >  27750.00
# |   |   |   |   |   |--- Monthly.Income <= 8833.33
# |   |   |   |   |   |   |--- value: [21.25]
# |   |   |   |   |   |--- Monthly.Income >  8833.33
# |   |   |   |   |   |   |--- value: [20.70]
# |--- FICO.Range >  704.50
# |   |--- Loan.Length_60 months <= 0.50
# |   |   |--- FICO.Range <= 729.50
# |   |   |   |--- Amount.Requested <= 12150.00
# |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |   |--- value: [11.12]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 7525.00
# |   |   |   |   |   |   |   |   |--- value: [9.09]
# |   |   |   |   |   |   |   |--- Amount.Requested >  7525.00
# |   |   |   |   |   |   |   |   |--- value: [9.99]
# |   |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [9.26]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  7.50
# |   |   |   |   |   |   |   |   |--- value: [8.24]
# |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |--- Amount.Requested <= 7437.50
# |   |   |   |   |   |   |   |--- value: [10.93]
# |   |   |   |   |   |   |--- Amount.Requested >  7437.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 4416.67
# |   |   |   |   |   |   |   |   |--- value: [12.51]
# |   |   |   |   |   |   |   |--- Monthly.Income >  4416.67
# |   |   |   |   |   |   |   |   |--- value: [11.98]
# |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |--- Amount.Requested <= 5337.50
# |   |   |   |   |   |   |   |--- value: [9.08]
# |   |   |   |   |   |   |--- Amount.Requested >  5337.50
# |   |   |   |   |   |   |   |--- Employment.Length <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |--- Employment.Length >  6.50
# |   |   |   |   |   |   |   |   |--- value: [11.37]
# |   |   |   |--- Amount.Requested >  12150.00
# |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |--- Amount.Requested <= 24275.00
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |   |--- value: [11.73]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |   |--- value: [13.03]
# |   |   |   |   |   |--- Amount.Requested >  24275.00
# |   |   |   |   |   |   |--- value: [14.84]
# |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |--- Amount.Requested <= 22500.00
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |   |--- value: [10.04]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |   |--- value: [11.31]
# |   |   |   |   |   |--- Amount.Requested >  22500.00
# |   |   |   |   |   |   |--- value: [11.92]
# |   |   |--- FICO.Range >  729.50
# |   |   |   |--- Amount.Requested <= 14550.00
# |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |--- FICO.Range <= 754.50
# |   |   |   |   |   |   |--- value: [10.64]
# |   |   |   |   |   |--- FICO.Range >  754.50
# |   |   |   |   |   |   |--- value: [8.32]
# |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |--- FICO.Range <= 749.50
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 1.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 7333.33
# |   |   |   |   |   |   |   |   |--- value: [7.40]
# |   |   |   |   |   |   |   |--- Monthly.Income >  7333.33
# |   |   |   |   |   |   |   |   |--- value: [8.31]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  1.50
# |   |   |   |   |   |   |   |--- value: [9.26]
# |   |   |   |   |   |--- FICO.Range >  749.50
# |   |   |   |   |   |   |--- State_TX <= 0.50
# |   |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 1.50
# |   |   |   |   |   |   |   |   |--- value: [6.75]
# |   |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  1.50
# |   |   |   |   |   |   |   |   |--- value: [7.46]
# |   |   |   |   |   |   |--- State_TX >  0.50
# |   |   |   |   |   |   |   |--- value: [8.20]
# |   |   |   |--- Amount.Requested >  14550.00
# |   |   |   |   |--- FICO.Range <= 764.50
# |   |   |   |   |   |--- Amount.Requested <= 24125.00
# |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 6916.00
# |   |   |   |   |   |   |   |--- value: [10.36]
# |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  6916.00
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 23197.00
# |   |   |   |   |   |   |   |   |--- value: [8.51]
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  23197.00
# |   |   |   |   |   |   |   |   |--- value: [10.26]
# |   |   |   |   |   |--- Amount.Requested >  24125.00
# |   |   |   |   |   |   |--- value: [11.03]
# |   |   |   |   |--- FICO.Range >  764.50
# |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 10931.50
# |   |   |   |   |   |   |--- value: [8.91]
# |   |   |   |   |   |--- Revolving.CREDIT.Balance >  10931.50
# |   |   |   |   |   |   |--- value: [7.49]
# |   |--- Loan.Length_60 months >  0.50
# |   |   |--- FICO.Range <= 729.50
# |   |   |   |--- Amount.Requested <= 25662.50
# |   |   |   |   |--- Amount.Requested <= 14500.00
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 8.50
# |   |   |   |   |   |   |--- value: [14.15]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  8.50
# |   |   |   |   |   |   |--- value: [12.41]
# |   |   |   |   |--- Amount.Requested >  14500.00
# |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |--- value: [16.38]
# |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |--- value: [14.75]
# |   |   |   |--- Amount.Requested >  25662.50
# |   |   |   |   |--- value: [18.51]
# |   |   |--- FICO.Range >  729.50
# |   |   |   |--- FICO.Range <= 754.50
# |   |   |   |   |--- Amount.Requested <= 20187.50
# |   |   |   |   |   |--- Amount.Requested <= 14200.00
# |   |   |   |   |   |   |--- value: [11.28]
# |   |   |   |   |   |--- Amount.Requested >  14200.00
# |   |   |   |   |   |   |--- value: [12.47]
# |   |   |   |   |--- Amount.Requested >  20187.50
# |   |   |   |   |   |--- value: [13.88]
# |   |   |   |--- FICO.Range >  754.50
# |   |   |   |   |--- Amount.Requested <= 23500.00
# |   |   |   |   |   |--- FICO.Range <= 779.50
# |   |   |   |   |   |   |--- value: [9.90]
# |   |   |   |   |   |--- FICO.Range >  779.50
# |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- Amount.Requested >  23500.00
# |   |   |   |   |   |--- value: [11.81]

# %%
x_train.columns
# Out:
# Index(['Loan.Length_36 months', 'Loan.Length_60 months',
#        'Loan.Purpose_debt_consolidation', 'Loan.Purpose_credit_card',
#        'Loan.Purpose_other', 'Loan.Purpose_home_improvement',
#        'Loan.Purpose_major_purchase', 'Loan.Purpose_small_business',
#        'Loan.Purpose___other__', 'Loan.Purpose_car', 'Loan.Purpose_wedding',
#        'Loan.Purpose_medical', 'State_CA', 'State_NY', 'State___other__',
#        'State_FL', 'State_TX', 'State_PA', 'State_IL', 'State_GA', 'State_NJ',
#        'State_VA', 'State_MA', 'State_NC', 'State_OH', 'State_MD', 'State_CO',
#        'State_WA', 'State_CT', 'State_AZ', 'State_MI', 'State_AL', 'State_MN',
#        'State_NV', 'State_MO', 'State_SC', 'State_OR',
#        'Home.Ownership_MORTGAGE', 'Home.Ownership_RENT', 'Home.Ownership_OWN',
#        'Amount.Requested', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#        'Monthly.Income', 'Inquiries.in.the.Last.6.Months',
#        'Debt.To.Income.Ratio', 'FICO.Range', 'Employment.Length'],
#       dtype='object')

# %%
feature_to_plot = ['FICO.Range']  # Replace with actual feature name

# Plot Partial Dependence
fig, ax = plt.subplots(figsize=(10, 6))
PartialDependenceDisplay.from_estimator(dt, x_train, feature_to_plot, ax=ax,kind='average')
plt.show()

# %%
features = [('Amount.Requested', 'FICO.Range')]  # Replace with actual column names

fig, ax = plt.subplots(figsize=(12, 8))
PartialDependenceDisplay.from_estimator(dt, x_train, features, ax=ax, kind="average")
plt.show()

# %% [markdown]
# # Regression Forest

# %%
x_train.shape
# Out:
# (2200, 48)

# %%
params_rf={
        'n_estimators':[50,100,150,200,250,300], # 6
        'max_features':[2,5,10,15,20,30,40,48],  # 7
        'bootstrap': [True,False], # 2
        'max_depth':[None,5,6,7,8,10,15,20,30,50], # 10
        'min_samples_leaf':[1,2,5,10,15,20], # 6
        'min_samples_split':[2,5,10,15,20] # 5
}

# %%
reg_rf=RandomForestRegressor()

# %%
rs_rf=RandomizedSearchCV(reg_rf,
                        cv=10,
                        param_distributions=params_rf,
                        scoring='neg_mean_absolute_error',
                        n_iter=50,
                        n_jobs=-1,
                        verbose=20)

# %%
rs_rf.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [CV 1/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 1/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.500 total time=   1.1s
# [CV 1/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 1/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.398 total time=   1.1s
# [CV 10/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 10/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.304 total time=   1.1s
# [CV 8/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 8/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.247 total time=   1.2s
# [CV 7/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 7/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.302 total time=   0.8s
# [CV 6/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 6/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.365 total time=   0.9s
# [CV 4/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.547 total time=   0.9s
# [CV 2/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 2/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.483 total time=   0.1s
# [CV 6/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 6/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.260 total time=   0.1s
# [CV 10/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 10/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.179 total time=   0.1s
# [CV 4/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 4/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.639 total time=   0.3s
# [CV 9/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 9/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.392 total time=   0.3s
# [CV 7/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 7/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.291 total time=   1.5s
# [CV 5/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 5/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.311 total time=   0.5s
# [CV 1/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 1/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.426 total time=   0.8s
# [CV 10/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 10/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.373 total time=   0.8s
# [CV 8/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 8/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.550 total time=   0.5s
# [CV 5/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 5/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.376 total time=   0.3s
# [CV 3/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.570 total time=   0.1s
# [CV 10/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 10/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.376 total time=   0.1s
# [CV 8/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 8/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.839 total time=   0.4s
# [CV 6/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 6/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.001 total time=   0.4s
# [CV 9/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 9/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.093 total time=   0.3s
# [CV 6/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 6/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.475 total time=   0.6s
# [CV 4/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 4/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.483 total time=   0.8s
# [CV 2/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 2/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.832 total time=   0.4s
# [CV 8/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 8/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.572 total time=   0.5s
# [CV 8/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 8/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.001 total time=   0.2s
# [CV 6/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200[CV 5/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 5/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.434 total time=   1.1s
# [CV 5/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 5/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.262 total time=   1.1s
# [CV 9/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 9/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.239 total time=   1.1s
# [CV 7/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 7/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.174 total time=   1.2s
# [CV 8/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 8/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.279 total time=   0.8s
# [CV 5/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 5/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.308 total time=   0.9s
# [CV 3/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.623 total time=   0.8s
# [CV 1/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 1/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.586 total time=   0.1s
# [CV 5/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 5/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.291 total time=   0.1s
# [CV 9/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 9/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.344 total time=   0.1s
# [CV 3/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 3/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.659 total time=   0.3s
# [CV 6/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 6/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.485 total time=   0.3s
# [CV 4/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 4/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.515 total time=   1.5s
# [CV 1/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 1/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.435 total time=   0.5s
# [CV 7/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 7/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.205 total time=   0.5s
# [CV 3/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 3/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.600 total time=   0.8s
# [CV 1/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 1/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.792 total time=   0.5s
# [CV 9/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 9/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.571 total time=   0.5s
# [CV 7/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 7/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.294 total time=   0.4s
# [CV 8/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 8/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.289 total time=   0.1s
# [CV 5/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 5/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.967 total time=   0.4s
# [CV 1/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 1/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.280 total time=   0.4s
# [CV 7/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 7/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-1.897 total time=   0.4s
# [CV 5/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 5/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.390 total time=   0.6s
# [CV 3/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 3/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.557 total time=   0.8s
# [CV 1/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 1/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.812 total time=   0.5s
# [CV 7/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 7/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.504 total time=   0.4s
# [CV 7/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 7/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-1.939 total time=   0.2s
# [CV 4/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200[CV 4/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 4/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.592 total time=   1.1s
# [CV 6/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 6/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.419 total time=   1.1s
# [CV 4/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 4/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.479 total time=   1.3s
# [CV 2/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.567 total time=   0.8s
# [CV 4/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 4/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.550 total time=   0.8s
# [CV 5/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 5/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.706 total time=   0.0s
# [CV 9/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 9/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.838 total time=   0.0s
# [CV 4/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 4/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.464 total time=   0.9s
# [CV 1/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.439 total time=   0.9s
# [CV 9/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 9/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.274 total time=   0.9s
# [CV 1/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 1/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.517 total time=   1.5s
# [CV 9/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 9/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.367 total time=   1.5s
# [CV 7/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 7/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.207 total time=   0.8s
# [CV 5/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 5/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.634 total time=   0.5s
# [CV 3/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 3/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.644 total time=   0.3s
# [CV 1/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.704 total time=   0.1s
# [CV 6/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 6/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.328 total time=   0.1s
# [CV 4/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 4/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-2.101 total time=   0.5s
# [CV 3/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 3/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.256 total time=   0.4s
# [CV 10/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 10/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.065 total time=   0.4s
# [CV 8/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 8/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.408 total time=   0.7s
# [CV 6/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 6/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.372 total time=   0.8s
# [CV 4/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 4/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.818 total time=   0.5s
# [CV 1/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 1/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.317 total time=   0.2s
# [CV 5/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 5/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.096 total time=   0.2s
# [CV 2/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 2/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.926 total time=   0.3s
# [CV 10/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 10/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.700 total time=   0.3s
# [CV 8/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 8/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.290 total time=   0.3s
# [CV 6/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300[CV 3/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 3/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.676 total time=   1.1s
# [CV 3/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.555 total time=   1.1s
# [CV 3/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 3/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.575 total time=   1.2s
# [CV 10/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 10/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.382 total time=   1.2s
# [CV 9/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 9/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.309 total time=   0.8s
# [CV 7/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 7/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.180 total time=   0.9s
# [CV 6/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 6/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.395 total time=   0.9s
# [CV 3/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 3/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.394 total time=   0.1s
# [CV 7/10; 8/50] START bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 7/10; 8/50] END bootstrap=True, max_depth=6, max_features=5, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-2.127 total time=   0.1s
# [CV 1/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 1/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.555 total time=   0.3s
# [CV 5/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 5/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.434 total time=   0.3s
# [CV 3/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 3/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.639 total time=   1.5s
# [CV 3/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 3/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.593 total time=   0.5s
# [CV 9/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 9/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.253 total time=   0.5s
# [CV 6/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 6/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.395 total time=   0.8s
# [CV 2/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 2/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.801 total time=   0.5s
# [CV 1/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 1/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.526 total time=   0.4s
# [CV 8/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 8/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.375 total time=   0.4s
# [CV 7/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 7/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.220 total time=   0.1s
# [CV 3/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 3/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-2.092 total time=   0.4s
# [CV 10/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 10/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.877 total time=   0.4s
# [CV 3/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 3/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.647 total time=   0.6s
# [CV 1/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 1/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.365 total time=   0.9s
# [CV 10/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 10/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.350 total time=   0.8s
# [CV 2/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 2/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.310 total time=   0.2s
# [CV 6/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 6/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.019 total time=   0.2s
# [CV 3/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 3/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.903 total time=   0.4s
# [CV 2/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 2/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.527 total time=   0.3s
# [CV 9/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50[CV 6/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 6/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.450 total time=   1.1s
# [CV 4/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 4/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.463 total time=   1.1s
# [CV 2/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 2/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.456 total time=   1.2s
# [CV 1/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.520 total time=   0.8s
# [CV 3/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.670 total time=   0.8s
# [CV 1/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 1/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-3.071 total time=   0.0s
# [CV 2/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 2/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.973 total time=   0.0s
# [CV 3/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 3/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.875 total time=   0.0s
# [CV 4/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 4/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.801 total time=   0.0s
# [CV 8/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 8/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.621 total time=   0.0s
# [CV 2/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 2/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.481 total time=   0.9s
# [CV 10/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 10/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.361 total time=   0.9s
# [CV 8/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 8/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.268 total time=   0.9s
# [CV 10/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 10/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.492 total time=   0.3s
# [CV 8/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 8/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.440 total time=   1.5s
# [CV 6/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 6/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.382 total time=   0.5s
# [CV 2/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 2/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.489 total time=   0.8s
# [CV 9/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 9/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.251 total time=   0.8s
# [CV 7/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 7/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.490 total time=   0.5s
# [CV 6/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 6/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.461 total time=   0.3s
# [CV 4/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.519 total time=   0.1s
# [CV 1/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 1/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-2.181 total time=   0.4s
# [CV 9/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 9/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.971 total time=   0.4s
# [CV 2/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 2/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.594 total time=   0.6s
# [CV 10/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 10/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.400 total time=   0.6s
# [CV 7/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 7/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.168 total time=   0.8s
# [CV 5/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 5/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.619 total time=   0.5s
# [CV 3/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 3/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.262 total time=   0.2s
# [CV 9/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200[CV 2/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 2/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.536 total time=   1.1s
# [CV 10/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 10/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.451 total time=   1.1s
# [CV 8/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 8/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.303 total time=   1.1s
# [CV 5/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 5/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.311 total time=   1.2s
# [CV 6/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 6/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.492 total time=   0.8s
# [CV 6/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 6/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.678 total time=   0.0s
# [CV 10/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 10/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.679 total time=   0.0s
# [CV 3/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 3/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.573 total time=   0.9s
# [CV 2/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.471 total time=   0.9s
# [CV 10/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 10/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.416 total time=   0.8s
# [CV 2/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 2/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.631 total time=   1.5s
# [CV 10/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 10/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.473 total time=   1.5s
# [CV 8/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 8/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.325 total time=   0.8s
# [CV 6/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 6/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.616 total time=   0.5s
# [CV 4/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 4/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.566 total time=   0.3s
# [CV 2/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.714 total time=   0.1s
# [CV 9/10; 15/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 9/10; 15/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=-2.487 total time=   0.1s
# [CV 6/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 6/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.899 total time=   0.5s
# [CV 4/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 4/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.166 total time=   0.4s
# [CV 4/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 4/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.561 total time=   0.6s
# [CV 2/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 2/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.460 total time=   0.8s
# [CV 9/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 9/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.195 total time=   0.8s
# [CV 10/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 10/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.612 total time=   0.5s
# [CV 5/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 5/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.740 total time=   0.4s
# [CV 3/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.598 total time=   0.3s
# [CV 1/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 1/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.464 total time=   1.9s
# [CV 9/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 9/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.331 total time=   1.8s
# [CV 9/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 9/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.225 total time=   1.2s
# [CV 1/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 5, 6, 7, 8, 10, 15,
#                                                       20, 30, 50],
#                                         'max_features': [2, 5, 10, 15, 20, 30,
#                                                          40, 48],
#                                         'min_samples_leaf': [1, 2, 5, 10, 15,
#                                                              20],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [50, 100, 150, 200, 250,
#                                                          300]},
#                    scoring='neg_mean_absolute_error', verbose=20)

# %%
mt.report(rs_rf.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: -1.345734 (std: 0.117456)
# Parameters: {'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 40, 'max_depth': 8, 'bootstrap': True}
#
# Model with rank: 2
# Mean validation score: -1.346785 (std: 0.121320)
# Parameters: {'n_estimators': 150, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 40, 'max_depth': None, 'bootstrap': True}
#
# Model with rank: 3
# Mean validation score: -1.361696 (std: 0.118066)
# Parameters: {'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 40, 'max_depth': 7, 'bootstrap': True}
#
# Model with rank: 4
# Mean validation score: -1.364035 (std: 0.111043)
# Parameters: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 20, 'max_depth': 50, 'bootstrap': False}
#
# Model with rank: 5
# Mean validation score: -1.367608 (std: 0.112163)
# Parameters: {'n_estimators': 250, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 30, 'max_depth': 10, 'bootstrap': True}

# %%
reg_rf=RandomForestRegressor(**{'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 40, 'max_depth': 8, 'bootstrap': True})

# %%
reg_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=8, max_features=40, min_samples_leaf=5,
#                       min_samples_split=15, n_estimators=200)

# %%
feat_imp_df=pd.DataFrame({'features':x_train.columns,'importance':reg_rf.feature_importances_})

# %%
feat_imp_df.sort_values(by='importance',ascending=False,inplace=True)
feat_imp_df['cum_importance']=feat_imp_df['importance'].cumsum()
feat_imp_df
# Out:
#                            features  importance  cum_importance
# 46                       FICO.Range    0.630658        0.630658
# 1             Loan.Length_60 months    0.137264        0.767922
# 40                 Amount.Requested    0.086102        0.854024
# 0             Loan.Length_36 months    0.070267        0.924291
# 44   Inquiries.in.the.Last.6.Months    0.019568        0.943858
# 41                Open.CREDIT.Lines    0.017782        0.961640
# 42         Revolving.CREDIT.Balance    0.010028        0.971668
# 45             Debt.To.Income.Ratio    0.009617        0.981285
# 43                   Monthly.Income    0.007857        0.989142
# 47                Employment.Length    0.003971        0.993113
# 37          Home.Ownership_MORTGAGE    0.001172        0.994285
# 4                Loan.Purpose_other    0.000924        0.995210
# 38              Home.Ownership_RENT    0.000897        0.996107
# 2   Loan.Purpose_debt_consolidation    0.000847        0.996954
# 12                         State_CA    0.000597        0.997550
# 16                         State_TX    0.000554        0.998104
# 3          Loan.Purpose_credit_card    0.000473        0.998578
# 7       Loan.Purpose_small_business    0.000311        0.998888
# 5     Loan.Purpose_home_improvement    0.000196        0.999084
# 14                  State___other__    0.000189        0.999273
# 15                         State_FL    0.000180        0.999454
# 13                         State_NY    0.000104        0.999557
# 28                         State_CT    0.000093        0.999650
# 6       Loan.Purpose_major_purchase    0.000082        0.999732
# 39               Home.Ownership_OWN    0.000076        0.999809
# 26                         State_CO    0.000060        0.999869
# 9                  Loan.Purpose_car    0.000053        0.999921
# 18                         State_IL    0.000023        0.999944
# 24                         State_OH    0.000021        0.999965
# 29                         State_AZ    0.000013        0.999978
# 30                         State_MI    0.000008        0.999986
# 8            Loan.Purpose___other__    0.000004        0.999990
# 17                         State_PA    0.000004        0.999994
# 19                         State_GA    0.000003        0.999997
# 20                         State_NJ    0.000003        1.000000
# 31                         State_AL    0.000000        1.000000
# 21                         State_VA    0.000000        1.000000
# 22                         State_MA    0.000000        1.000000
# 23                         State_NC    0.000000        1.000000
# 25                         State_MD    0.000000        1.000000
# 27                         State_WA    0.000000        1.000000
# 11             Loan.Purpose_medical    0.000000        1.000000
# 36                         State_OR    0.000000        1.000000
# 35                         State_SC    0.000000        1.000000
# 34                         State_MO    0.000000        1.000000
# 33                         State_NV    0.000000        1.000000
# 32                         State_MN    0.000000        1.000000
# 10             Loan.Purpose_wedding    0.000000        1.000000

# %%
feature_to_plot = ['FICO.Range']  # Replace with actual feature name

# Plot Partial Dependence
fig, ax = plt.subplots(figsize=(10, 6))
PartialDependenceDisplay.from_estimator(reg_rf, x_train, feature_to_plot, ax=ax,kind='average')
plt.show()

# %%
features = [('Amount.Requested', 'FICO.Range')]  # Replace with actual column names

fig, ax = plt.subplots(figsize=(12, 8))
PartialDependenceDisplay.from_estimator(rs_rf, x_train, features, ax=ax, kind="average")
plt.show()
# Out:
# [CV 1/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-2.094 total time=   0.4s
# [CV 3/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 3/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-2.042 total time=   0.4s
# [CV 10/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 10/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-1.824 total time=   0.4s
# [CV 8/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 8/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.245 total time=   0.8s
# [CV 5/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 5/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.342 total time=   1.3s
# [CV 3/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.634 total time=   0.1s
# [CV 7/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 7/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.343 total time=   0.1s
# [CV 1/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-3.115 total time=   0.0s
# [CV 3/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-3.055 total time=   0.0s
# [CV 7/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 7/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.539 total time=   0.0s
# [CV 1/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.343 total time=   0.1s
# [CV 5/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 5/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.133 total time=   0.1s
# [CV 10/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 10/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.156 total time=   0.1s
# [CV 5/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 5/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.614 total time=   0.2s
# [CV 5/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 5/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.655 total time=   0.1s
# [CV 6/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 6/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.646 total time=   0.2s
# [CV 7/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 7/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.348 total time=   0.4s
# [CV 8/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 8/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.362 total time=   0.4s
# [CV 1/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 1/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.714 total time=   0.1s
# [CV 2/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 2/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.677 total time=   0.1s
# [CV 7/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 7/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.473 total time=   0.1s
# [CV 8/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 8/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.520 total time=   0.1s
# [CV 3/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.853 total time=   0.3s
# [CV 4/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 4/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.831 total time=   0.3s
# [CV 5/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 5/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.361 total time=   0.4s
# [CV 6/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 6/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.400 total time=   0.4s
# [CV 7/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 7/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.634 total time=   0.4s
# [CV 8/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 8/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.669 total time=   0.4s
# [CV 9/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 9/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.334 total time=   1.9s
# [CV 10/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 10/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.558 total time=   1.9s
# [CV 5/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 5/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.486 total time=   0.3s
# [CV 6/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 6/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.532 total time=   0.3s
# [CV 1/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 1/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.935 total time=   0.0s
# [CV 2/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 2/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.955 total time=   0.0s
# [CV 3/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 3/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.851 total time=   0.0s
# [CV 4/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 4/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.734 total time=   0.0s
# [CV 5/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 5/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.681 total time=   0.0s
# [CV 6/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 6/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.718 total time=   0.1s
# [CV 7/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 7/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.505 total time=   0.0s
# [CV 8/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 8/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.437 total time=   0.0s
# [CV 9/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 9/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.783 total time=   0.0s
# [CV 10/10; 50/50] START bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50
# [CV 10/10; 50/50] END bootstrap=False, max_depth=6, max_features=2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=-2.699 total time=   0.0s
#
# [CV 4/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.925 total time=   0.3s
# [CV 1/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.415 total time=   0.3s
# [CV 10/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 10/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.367 total time=   0.3s
# [CV 8/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 8/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.317 total time=   1.9s
# [CV 5/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 5/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.877 total time=   0.3s
# [CV 1/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 1/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.411 total time=   1.2s
# [CV 7/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 7/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.175 total time=   1.2s
# [CV 9/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 9/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.268 total time=   0.8s
# [CV 9/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 9/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-1.812 total time=   0.4s
# [CV 7/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 7/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.154 total time=   0.9s
# [CV 6/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 6/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.437 total time=   1.3s
# [CV 5/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 5/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.403 total time=   0.1s
# [CV 9/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 9/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.292 total time=   0.1s
# [CV 5/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 5/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.702 total time=   0.0s
# [CV 9/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 9/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.957 total time=   0.0s
# [CV 2/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.277 total time=   0.1s
# [CV 6/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 6/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.082 total time=   0.1s
# [CV 1/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 1/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.832 total time=   0.2s
# [CV 7/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 7/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.419 total time=   0.2s
# [CV 8/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 8/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.487 total time=   0.2s
# [CV 9/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 9/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.407 total time=   0.5s
# [CV 10/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 10/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.493 total time=   0.4s
# [CV 5/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 5/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.540 total time=   0.1s
# [CV 6/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 6/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.588 total time=   0.1s
# [CV 1/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.847 total time=   0.3s
# [CV 2/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.794 total time=   0.3s
# [CV 3/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 3/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.601 total time=   0.4s
# [CV 4/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 4/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.527 total time=   0.4s
# [CV 3/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 3/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.903 total time=   0.4s
# [CV 4/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 4/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.888 total time=   0.4s
# [CV 9/10; 45/50] START bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 9/10; 45/50] END bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-1.365 total time=   0.2s
# [CV 10/10; 45/50] START bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 10/10; 45/50] END bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-1.448 total time=   0.2s
# [CV 5/10; 47/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 5/10; 47/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.913 total time=   0.3s
# [CV 6/10; 47/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 6/10; 47/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.865 total time=   0.3s
# [CV 1/10; 48/50] START bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250
# [CV 1/10; 48/50] END bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250;, score=-1.487 total time=   2.0s
# [CV 2/10; 48/50] START bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250
# [CV 2/10; 48/50] END bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250;, score=-1.540 total time=   2.1s
#
# [CV 6/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.429 total time=   1.8s
# [CV 2/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 2/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-2.035 total time=   0.3s
# [CV 8/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 8/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.754 total time=   0.3s
# [CV 3/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 3/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.587 total time=   1.2s
# [CV 1/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 1/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.441 total time=   0.9s
# [CV 7/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 7/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.234 total time=   0.9s
# [CV 7/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 7/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-1.706 total time=   0.4s
# [CV 5/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 5/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.296 total time=   0.9s
# [CV 3/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 3/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.577 total time=   1.2s
# [CV 1/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.582 total time=   0.2s
# [CV 4/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 4/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.629 total time=   0.1s
# [CV 8/10; 31/50] START bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 8/10; 31/50] END bootstrap=True, max_depth=15, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-1.412 total time=   0.1s
# [CV 2/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.911 total time=   0.0s
# [CV 4/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 4/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.905 total time=   0.0s
# [CV 8/10; 32/50] START bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 8/10; 32/50] END bootstrap=True, max_depth=5, max_features=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.695 total time=   0.0s
# [CV 4/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 4/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.252 total time=   0.1s
# [CV 8/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 8/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.057 total time=   0.1s
# [CV 3/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 3/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.775 total time=   0.2s
# [CV 1/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 1/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.866 total time=   0.2s
# [CV 2/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 2/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.873 total time=   0.1s
# [CV 3/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 3/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.695 total time=   0.4s
# [CV 4/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 4/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.622 total time=   0.4s
# [CV 9/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 9/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.309 total time=   0.5s
# [CV 10/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 10/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.380 total time=   0.5s
# [CV 9/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 9/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.305 total time=   0.4s
# [CV 10/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 10/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.369 total time=   0.4s
# [CV 1/10; 44/50] START bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/10; 44/50] END bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=-2.216 total time=   0.1s
# [CV 2/10; 44/50] START bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/10; 44/50] END bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=-2.318 total time=   0.1s
# [CV 5/10; 44/50] START bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 5/10; 44/50] END bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=-2.023 total time=   0.1s
# [CV 6/10; 44/50] START bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 6/10; 44/50] END bootstrap=True, max_depth=8, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=-1.883 total time=   0.1s
# [CV 1/10; 45/50] START bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/10; 45/50] END bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-1.532 total time=   0.2s
# [CV 2/10; 45/50] START bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/10; 45/50] END bootstrap=False, max_depth=7, max_features=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-1.516 total time=   0.2s
# [CV 1/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 1/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.616 total time=   1.8s
# [CV 2/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 2/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.613 total time=   1.9s
# [CV 1/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 1/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.665 total time=   0.3s
# [CV 2/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 2/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.690 total time=   0.3s
# [CV 7/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 7/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.435 total time=   0.3s
# [CV 8/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 8/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.505 total time=   0.3s
#
# [CV 9/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.179 total time=   0.2s
# [CV 8/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 8/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.656 total time=   0.3s
# [CV 5/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 5/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.317 total time=   0.3s
# [CV 4/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 4/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.423 total time=   1.8s
# [CV 1/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 1/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-2.148 total time=   0.3s
# [CV 6/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 6/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.837 total time=   0.3s
# [CV 2/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 2/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.471 total time=   1.2s
# [CV 8/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 8/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.296 total time=   1.2s
# [CV 10/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 10/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.343 total time=   0.8s
# [CV 1/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 1/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.387 total time=   0.9s
# [CV 9/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 9/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.212 total time=   0.9s
# [CV 7/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 7/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.200 total time=   1.2s
# [CV 9/10; 33/50] START bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 9/10; 33/50] END bootstrap=False, max_depth=7, max_features=5, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-2.028 total time=   0.1s
# [CV 4/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 4/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.741 total time=   0.2s
# [CV 3/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 3/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.840 total time=   0.2s
# [CV 4/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 4/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.773 total time=   0.2s
# [CV 5/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 5/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.472 total time=   0.4s
# [CV 6/10; 36/50] START bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150
# [CV 6/10; 36/50] END bootstrap=False, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=15, n_estimators=150;, score=-1.502 total time=   0.4s
# [CV 3/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 3/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.748 total time=   0.1s
# [CV 4/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 4/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.761 total time=   0.1s
# [CV 9/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 9/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.499 total time=   0.1s
# [CV 10/10; 39/50] START bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50
# [CV 10/10; 39/50] END bootstrap=True, max_depth=6, max_features=15, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=-1.531 total time=   0.1s
# [CV 5/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 5/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.601 total time=   0.3s
# [CV 6/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 6/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.638 total time=   0.3s
# [CV 7/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 7/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.249 total time=   0.4s
# [CV 8/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# [CV 8/10; 41/50] END bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150;, score=-1.358 total time=   0.4s
# [CV 9/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 9/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.739 total time=   0.4s
# [CV 10/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 10/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.755 total time=   0.4s
# [CV 7/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 7/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.300 total time=   1.8s
# [CV 8/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 8/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.322 total time=   1.9s
# [CV 3/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 3/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.744 total time=   0.3s
# [CV 4/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 4/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.679 total time=   0.3s
# [CV 9/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 9/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.494 total time=   0.3s
# [CV 10/10; 49/50] START bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150
# [CV 10/10; 49/50] END bootstrap=True, max_depth=None, max_features=15, min_samples_leaf=20, min_samples_split=15, n_estimators=150;, score=-1.526 total time=   0.3s
#
# [CV 9/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.268 total time=   0.3s
# [CV 7/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 7/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.198 total time=   1.8s
# [CV 4/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 4/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-2.024 total time=   0.3s
# [CV 10/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 10/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.878 total time=   0.3s
# [CV 6/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 6/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.389 total time=   1.2s
# [CV 3/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 3/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.569 total time=   0.8s
# [CV 5/10; 27/50] START bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200
# [CV 5/10; 27/50] END bootstrap=False, max_depth=None, max_features=15, min_samples_leaf=1, min_samples_split=15, n_estimators=200;, score=-1.297 total time=   0.8s
# [CV 5/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 5/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-1.877 total time=   0.4s
# [CV 2/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 2/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.438 total time=   0.9s
# [CV 1/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 1/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.475 total time=   1.2s
# [CV 9/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 9/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.337 total time=   1.2s
# [CV 9/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 9/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.619 total time=   0.1s
# [CV 10/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 10/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.643 total time=   0.1s
# [CV 9/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 9/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.143 total time=   0.1s
# [CV 10/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 10/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.032 total time=   0.1s
# [CV 5/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 5/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.376 total time=   0.5s
# [CV 6/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 6/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.423 total time=   0.5s
# [CV 1/10; 41/50] START bootstrap=True, max_depth=50, max_features=20, min_samples_leaf=10, min_samples_split=20, n_estimators=150
# ...
# [CV 9/10; 1/50] START bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 9/10; 1/50] END bootstrap=True, max_depth=5, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.301 total time=   1.0s
# [CV 7/10; 2/50] START bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 7/10; 2/50] END bootstrap=False, max_depth=50, max_features=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-1.209 total time=   1.1s
# [CV 6/10; 3/50] START bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300
# [CV 6/10; 3/50] END bootstrap=True, max_depth=7, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300;, score=-1.364 total time=   1.2s
# [CV 5/10; 4/50] START bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/10; 4/50] END bootstrap=False, max_depth=6, max_features=40, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-1.432 total time=   0.8s
# [CV 7/10; 5/50] START bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50
# [CV 7/10; 5/50] END bootstrap=True, max_depth=15, max_features=2, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=-2.456 total time=   0.0s
# [CV 1/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 1/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.406 total time=   0.8s
# [CV 9/10; 6/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250
# [CV 9/10; 6/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=10, min_samples_split=10, n_estimators=250;, score=-1.240 total time=   0.9s
# [CV 7/10; 7/50] START bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 7/10; 7/50] END bootstrap=True, max_depth=6, max_features=48, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=-1.244 total time=   0.8s
# [CV 7/10; 9/50] START bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 7/10; 9/50] END bootstrap=True, max_depth=6, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=-1.342 total time=   0.3s
# [CV 5/10; 10/50] START bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 5/10; 10/50] END bootstrap=False, max_depth=None, max_features=48, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.472 total time=   1.5s
# [CV 2/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 2/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.495 total time=   0.5s
# [CV 8/10; 11/50] START bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 8/10; 11/50] END bootstrap=True, max_depth=None, max_features=30, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.328 total time=   0.5s
# [CV 4/10; 12/50] START bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250
# [CV 4/10; 12/50] END bootstrap=True, max_depth=10, max_features=30, min_samples_leaf=15, min_samples_split=15, n_estimators=250;, score=-1.511 total time=   0.8s
# [CV 3/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 3/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.816 total time=   0.5s
# [CV 10/10; 13/50] START bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250
# [CV 10/10; 13/50] END bootstrap=False, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=20, n_estimators=250;, score=-1.590 total time=   0.5s
# [CV 10/10; 14/50] START bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150
# [CV 10/10; 14/50] END bootstrap=True, max_depth=20, max_features=15, min_samples_leaf=5, min_samples_split=20, n_estimators=150;, score=-1.408 total time=   0.4s
# [CV 7/10; 16/50] START bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250
# [CV 7/10; 16/50] END bootstrap=True, max_depth=None, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=-1.812 total time=   0.5s
# [CV 5/10; 17/50] START bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300
# [CV 5/10; 17/50] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=-2.105 total time=   0.4s
# [CV 1/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 1/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.543 total time=   0.6s
# [CV 9/10; 18/50] START bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 9/10; 18/50] END bootstrap=False, max_depth=None, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.345 total time=   0.6s
# [CV 8/10; 19/50] START bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150
# [CV 8/10; 19/50] END bootstrap=True, max_depth=None, max_features=40, min_samples_leaf=1, min_samples_split=20, n_estimators=150;, score=-1.261 total time=   0.8s
# [CV 6/10; 20/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300
# [CV 6/10; 20/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=15, n_estimators=300;, score=-1.622 total time=   0.4s
# [CV 4/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 4/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.287 total time=   0.2s
# [CV 10/10; 21/50] START bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200
# [CV 10/10; 21/50] END bootstrap=True, max_depth=7, max_features=5, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=-2.033 total time=   0.2s
# [CV 7/10; 22/50] START bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 7/10; 22/50] END bootstrap=True, max_depth=6, max_features=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=-1.607 total time=   0.3s
# [CV 6/10; 23/50] START bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 6/10; 23/50] END bootstrap=False, max_depth=15, max_features=30, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=-1.393 total time=   0.3s
# [CV 3/10; 24/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300
# [CV 3/10; 24/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=5, n_estimators=300;, score=-1.582 total time=   1.9s
# [CV 3/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 3/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-2.074 total time=   0.3s
# [CV 9/10; 25/50] START bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200
# [CV 9/10; 25/50] END bootstrap=False, max_depth=5, max_features=10, min_samples_leaf=15, min_samples_split=20, n_estimators=200;, score=-1.880 total time=   0.3s
# [CV 5/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 5/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.317 total time=   1.2s
# [CV 10/10; 26/50] START bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300
# [CV 10/10; 26/50] END bootstrap=True, max_depth=30, max_features=40, min_samples_leaf=15, min_samples_split=2, n_estimators=300;, score=-1.357 total time=   1.3s
# [CV 2/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 2/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-2.029 total time=   0.4s
# [CV 4/10; 28/50] START bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# [CV 4/10; 28/50] END bootstrap=True, max_depth=30, max_features=5, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-1.972 total time=   0.4s
# [CV 3/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 3/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.570 total time=   0.9s
# [CV 10/10; 29/50] START bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200
# [CV 10/10; 29/50] END bootstrap=True, max_depth=8, max_features=40, min_samples_leaf=5, min_samples_split=15, n_estimators=200;, score=-1.352 total time=   0.9s
# [CV 8/10; 30/50] START bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200
# [CV 8/10; 30/50] END bootstrap=False, max_depth=8, max_features=40, min_samples_leaf=10, min_samples_split=20, n_estimators=200;, score=-1.308 total time=   1.2s
# [CV 6/10; 34/50] START bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300
# [CV 6/10; 34/50] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=15, min_samples_split=15, n_estimators=300;, score=-2.590 total time=   0.2s
# [CV 7/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 7/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.530 total time=   0.2s
# [CV 8/10; 35/50] START bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100
# [CV 8/10; 35/50] END bootstrap=True, max_depth=20, max_features=10, min_samples_leaf=15, min_samples_split=5, n_estimators=100;, score=-1.617 total time=   0.1s
# [CV 1/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 1/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.259 total time=   0.1s
# [CV 2/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.398 total time=   0.1s
# [CV 7/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 7/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.023 total time=   0.1s
# [CV 8/10; 37/50] START bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 8/10; 37/50] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-2.039 total time=   0.1s
# [CV 3/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 3/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.638 total time=   0.5s
# [CV 4/10; 38/50] START bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150
# [CV 4/10; 38/50] END bootstrap=False, max_depth=None, max_features=20, min_samples_leaf=15, min_samples_split=5, n_estimators=150;, score=-1.512 total time=   0.5s
# [CV 9/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 9/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.645 total time=   0.3s
# [CV 10/10; 40/50] START bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 10/10; 40/50] END bootstrap=True, max_depth=8, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-1.638 total time=   0.3s
# [CV 5/10; 42/50] START bootstrap=True, max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=250
# [CV 5/10; 42/50] END bootstrap=True, max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=250;, score=-2.093 total time=   0.3s
# [CV 6/10; 42/50] START bootstrap=True, max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=250
# [CV 6/10; 42/50] END bootstrap=True, max_depth=15, max_features=5, min_samples_leaf=15, min_samples_split=5, n_estimators=250;, score=-1.992 total time=   0.2s
# [CV 5/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 5/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.728 total time=   0.4s
# [CV 6/10; 43/50] START bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300
# [CV 6/10; 43/50] END bootstrap=True, max_depth=20, max_features=5, min_samples_leaf=2, min_samples_split=15, n_estimators=300;, score=-1.716 total time=   0.4s
# [CV 3/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 3/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.722 total time=   1.8s
# [CV 4/10; 46/50] START bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300
# [CV 4/10; 46/50] END bootstrap=False, max_depth=6, max_features=48, min_samples_leaf=20, min_samples_split=10, n_estimators=300;, score=-1.597 total time=   1.9s
# [CV 9/10; 48/50] START bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250
# [CV 9/10; 48/50] END bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250;, score=-1.323 total time=   1.9s
# [CV 10/10; 48/50] START bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250
# [CV 10/10; 48/50] END bootstrap=False, max_depth=20, max_features=40, min_samples_leaf=5, min_samples_split=20, n_estimators=250;, score=-1.397 total time=   1.6s
