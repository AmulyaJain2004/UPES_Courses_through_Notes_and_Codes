# %%
import ml_utils as mt 
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor,plot_tree
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,ExtraTreesClassifier,ExtraTreesRegressor
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt 
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Regression Trees

# %%
ld_train=pd.read_csv('loan_data_train.csv')
def custom_dir(dir_col):
    
    temp=dir_col.str.replace('%','')
    num=pd.to_numeric(temp,errors='coerce')
    
    return num

def custom_fico(fico_col):
    
    temp=fico_col.str.split('-',expand=True)
    for i in [0,1]:
        temp[i]=pd.to_numeric(temp[i],errors='coerce')
    num=0.5*(temp[0]+temp[1])
    
    return num

def custom_el(el_col):
    temp=el_col.replace({'5 years':5, '4 years':4, '< 1 year':0, 
           '10+ years':10, '2 years':2,'8 years':8, 
           '1 year':1, '6 years':6, '7 years':7, 
           '3 years':3, '9 years':9})
    num=pd.to_numeric(temp,errors='coerce')
    return num

cat_to_num_cols=['Amount.Requested',
                'Open.CREDIT.Lines','Revolving.CREDIT.Balance']
simple_num_cols=['Monthly.Income','Inquiries.in.the.Last.6.Months']
cat_to_dummies_cols=[ 'Loan.Length','Loan.Purpose',
                    'State','Home.Ownership']
custom_func_cols={'Debt.To.Income.Ratio':custom_dir,
                    'FICO.Range':custom_fico,
                    'Employment.Length':custom_el}
ld_pipe=mt.DataPipe(simple_num=simple_num_cols,
                   cat_to_num=cat_to_num_cols,
                   cat_to_dummies=cat_to_dummies_cols,
                   custom_func_dict=custom_func_cols)
ld_pipe.fit(ld_train)
x_train=ld_pipe.transform(ld_train)
y_train=ld_train['Interest.Rate'].str.replace('%','').astype(float)
# Out:
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=pd.to_numeric(x[col],errors='coerce')
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=pd.to_numeric(x[col],errors='coerce')
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])
# d:\my_codes_26_12_24_1\upes_repo\UPES_Courses_through_Notes_and_Codes\ML-DL-Intensive_Training\Day-10_12-02-25\ml_utils.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[col]=self.col_func_dict[col](x[col])

# %%
params={
        'max_depth':[None,5,6,7,8,10,15,20,30,50], # 10
        'min_samples_leaf':[1,2,5,10,15,20], # 6
        'min_samples_split':[2,5,10,15,20] # 5
        }

# %%
reg=DecisionTreeRegressor()

# %%
rs=RandomizedSearchCV(reg,
                     cv=10,
                     param_distributions=params,
                     scoring='neg_mean_absolute_error',
                     n_iter=50,
                     n_jobs=-1,
                     verbose=20)

# %%
rs.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# RandomizedSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [None, 5, 6, 7, 8, 10, 15,
#                                                       20, 30, 50],
#                                         'min_samples_leaf': [1, 2, 5, 10, 15,
#                                                              20],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               20]},
#                    scoring='neg_mean_absolute_error', verbose=20)

# %%
mt.report(rs.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: -1.472019 (std: 0.105327)
# Parameters: {'min_samples_split': 10, 'min_samples_leaf': 15, 'max_depth': 8}
#
# Model with rank: 2
# Mean validation score: -1.481331 (std: 0.128994)
# Parameters: {'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 7}
#
# Model with rank: 3
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': None}
#
# Model with rank: 3
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 30}
#
# Model with rank: 3
# Mean validation score: -1.484124 (std: 0.120845)
# Parameters: {'min_samples_split': 15, 'min_samples_leaf': 20, 'max_depth': 15}

# %%
dt=DecisionTreeRegressor(**{'min_samples_split': 5, 'min_samples_leaf': 15, 'max_depth': 8})

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=15, min_samples_split=5)

# %%
from sklearn.tree import export_graphviz
import graphviz

# Generate DOT data
dot_data = export_graphviz(
    dt,
    out_file=None,  # No file output, just return as a string
    feature_names=x_train.columns,
    class_names=["0", "1"],
    filled=True,
    rounded=True,
    special_characters=True
)

# Render with Graphviz
graph = graphviz.Source(dot_data)
graph.render("decision_tree", format="png", cleanup=True)  # Saves as a high-quality PNG
graph  # Display in Jupyter Notebook (if applicable)

# %%
from sklearn.tree import export_text

tree_rules = export_text(dt, feature_names=x_train.columns)
print(tree_rules)
# Out:
# |--- FICO.Range <= 704.50
# |   |--- Loan.Length_60 months <= 0.50
# |   |   |--- FICO.Range <= 679.50
# |   |   |   |--- Amount.Requested <= 13062.50
# |   |   |   |   |--- FICO.Range <= 669.50
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6037.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 22.72
# |   |   |   |   |   |   |   |   |--- value: [15.15]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  22.72
# |   |   |   |   |   |   |   |   |--- value: [16.71]
# |   |   |   |   |   |   |--- Amount.Requested >  6037.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 11.07
# |   |   |   |   |   |   |   |   |--- value: [15.42]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  11.07
# |   |   |   |   |   |   |   |   |--- value: [17.15]
# |   |   |   |   |--- FICO.Range >  669.50
# |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 6500.00
# |   |   |   |   |   |   |   |   |--- value: [13.89]
# |   |   |   |   |   |   |   |--- Amount.Requested >  6500.00
# |   |   |   |   |   |   |   |   |--- value: [15.03]
# |   |   |   |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 13.57
# |   |   |   |   |   |   |   |   |--- value: [12.90]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  13.57
# |   |   |   |   |   |   |   |   |--- value: [13.98]
# |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6862.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 3708.33
# |   |   |   |   |   |   |   |   |--- value: [14.26]
# |   |   |   |   |   |   |   |--- Monthly.Income >  3708.33
# |   |   |   |   |   |   |   |   |--- value: [15.23]
# |   |   |   |   |   |   |--- Amount.Requested >  6862.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 5735.04
# |   |   |   |   |   |   |   |   |--- value: [16.10]
# |   |   |   |   |   |   |   |--- Monthly.Income >  5735.04
# |   |   |   |   |   |   |   |   |--- value: [15.02]
# |   |   |   |--- Amount.Requested >  13062.50
# |   |   |   |   |--- FICO.Range <= 669.50
# |   |   |   |   |   |--- Amount.Requested <= 18575.00
# |   |   |   |   |   |   |--- value: [18.11]
# |   |   |   |   |   |--- Amount.Requested >  18575.00
# |   |   |   |   |   |   |--- value: [19.87]
# |   |   |   |   |--- FICO.Range >  669.50
# |   |   |   |   |   |--- Amount.Requested <= 18112.50
# |   |   |   |   |   |   |--- value: [16.26]
# |   |   |   |   |   |--- Amount.Requested >  18112.50
# |   |   |   |   |   |   |--- value: [18.01]
# |   |   |--- FICO.Range >  679.50
# |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |--- Amount.Requested <= 22950.00
# |   |   |   |   |   |--- Amount.Requested <= 7350.00
# |   |   |   |   |   |   |--- FICO.Range <= 694.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [12.78]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  7.50
# |   |   |   |   |   |   |   |   |--- value: [11.74]
# |   |   |   |   |   |   |--- FICO.Range >  694.50
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 15.62
# |   |   |   |   |   |   |   |   |--- value: [11.15]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  15.62
# |   |   |   |   |   |   |   |   |--- value: [9.78]
# |   |   |   |   |   |--- Amount.Requested >  7350.00
# |   |   |   |   |   |   |--- FICO.Range <= 699.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [14.41]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  6.50
# |   |   |   |   |   |   |   |   |--- value: [12.78]
# |   |   |   |   |   |   |--- FICO.Range >  699.50
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 11251.50
# |   |   |   |   |   |   |   |   |--- value: [11.24]
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  11251.50
# |   |   |   |   |   |   |   |   |--- value: [11.99]
# |   |   |   |   |--- Amount.Requested >  22950.00
# |   |   |   |   |   |--- value: [15.84]
# |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |--- Amount.Requested <= 16037.50
# |   |   |   |   |   |--- FICO.Range <= 684.50
# |   |   |   |   |   |   |--- Amount.Requested <= 6750.00
# |   |   |   |   |   |   |   |--- value: [13.79]
# |   |   |   |   |   |   |--- Amount.Requested >  6750.00
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio <= 19.06
# |   |   |   |   |   |   |   |   |--- value: [14.90]
# |   |   |   |   |   |   |   |--- Debt.To.Income.Ratio >  19.06
# |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |--- FICO.Range >  684.50
# |   |   |   |   |   |   |--- Home.Ownership_MORTGAGE <= 0.50
# |   |   |   |   |   |   |   |--- Loan.Purpose_debt_consolidation <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [14.11]
# |   |   |   |   |   |   |   |--- Loan.Purpose_debt_consolidation >  0.50
# |   |   |   |   |   |   |   |   |--- value: [13.27]
# |   |   |   |   |   |   |--- Home.Ownership_MORTGAGE >  0.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 9700.00
# |   |   |   |   |   |   |   |   |--- value: [12.56]
# |   |   |   |   |   |   |   |--- Amount.Requested >  9700.00
# |   |   |   |   |   |   |   |   |--- value: [13.48]
# |   |   |   |   |--- Amount.Requested >  16037.50
# |   |   |   |   |   |--- Debt.To.Income.Ratio <= 18.03
# |   |   |   |   |   |   |--- value: [15.50]
# |   |   |   |   |   |--- Debt.To.Income.Ratio >  18.03
# |   |   |   |   |   |   |--- value: [16.61]
# |   |--- Loan.Length_60 months >  0.50
# |   |   |--- Amount.Requested <= 16325.00
# |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |--- Revolving.CREDIT.Balance <= 7840.00
# |   |   |   |   |   |--- value: [18.60]
# |   |   |   |   |--- Revolving.CREDIT.Balance >  7840.00
# |   |   |   |   |   |--- value: [20.09]
# |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |--- FICO.Range <= 699.50
# |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 10940.00
# |   |   |   |   |   |   |--- Amount.Requested <= 8525.00
# |   |   |   |   |   |   |   |--- value: [15.90]
# |   |   |   |   |   |   |--- Amount.Requested >  8525.00
# |   |   |   |   |   |   |   |--- value: [16.74]
# |   |   |   |   |   |--- Revolving.CREDIT.Balance >  10940.00
# |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |--- FICO.Range >  699.50
# |   |   |   |   |   |--- value: [15.05]
# |   |   |--- Amount.Requested >  16325.00
# |   |   |   |--- FICO.Range <= 674.50
# |   |   |   |   |--- Employment.Length <= 7.50
# |   |   |   |   |   |--- value: [22.09]
# |   |   |   |   |--- Employment.Length >  7.50
# |   |   |   |   |   |--- value: [22.88]
# |   |   |   |--- FICO.Range >  674.50
# |   |   |   |   |--- Amount.Requested <= 27750.00
# |   |   |   |   |   |--- FICO.Range <= 694.50
# |   |   |   |   |   |   |--- Amount.Requested <= 20875.00
# |   |   |   |   |   |   |   |--- value: [18.83]
# |   |   |   |   |   |   |--- Amount.Requested >  20875.00
# |   |   |   |   |   |   |   |--- value: [19.87]
# |   |   |   |   |   |--- FICO.Range >  694.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- Amount.Requested >  27750.00
# |   |   |   |   |   |--- Monthly.Income <= 8833.33
# |   |   |   |   |   |   |--- value: [21.25]
# |   |   |   |   |   |--- Monthly.Income >  8833.33
# |   |   |   |   |   |   |--- value: [20.70]
# |--- FICO.Range >  704.50
# |   |--- Loan.Length_60 months <= 0.50
# |   |   |--- FICO.Range <= 729.50
# |   |   |   |--- Amount.Requested <= 12150.00
# |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |   |--- value: [11.12]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |   |--- Amount.Requested <= 7525.00
# |   |   |   |   |   |   |   |   |--- value: [9.09]
# |   |   |   |   |   |   |   |--- Amount.Requested >  7525.00
# |   |   |   |   |   |   |   |   |--- value: [9.99]
# |   |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [9.26]
# |   |   |   |   |   |   |   |--- Open.CREDIT.Lines >  7.50
# |   |   |   |   |   |   |   |   |--- value: [8.24]
# |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |--- Amount.Requested <= 7437.50
# |   |   |   |   |   |   |   |--- value: [10.93]
# |   |   |   |   |   |   |--- Amount.Requested >  7437.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 4416.67
# |   |   |   |   |   |   |   |   |--- value: [12.51]
# |   |   |   |   |   |   |   |--- Monthly.Income >  4416.67
# |   |   |   |   |   |   |   |   |--- value: [11.98]
# |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |--- Amount.Requested <= 5337.50
# |   |   |   |   |   |   |   |--- value: [9.08]
# |   |   |   |   |   |   |--- Amount.Requested >  5337.50
# |   |   |   |   |   |   |   |--- Employment.Length <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |--- Employment.Length >  6.50
# |   |   |   |   |   |   |   |   |--- value: [11.37]
# |   |   |   |--- Amount.Requested >  12150.00
# |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |--- Amount.Requested <= 24275.00
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |   |--- value: [11.73]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |   |--- value: [13.03]
# |   |   |   |   |   |--- Amount.Requested >  24275.00
# |   |   |   |   |   |   |--- value: [14.84]
# |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |--- Amount.Requested <= 22500.00
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 0.50
# |   |   |   |   |   |   |   |--- value: [10.04]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  0.50
# |   |   |   |   |   |   |   |--- value: [11.31]
# |   |   |   |   |   |--- Amount.Requested >  22500.00
# |   |   |   |   |   |   |--- value: [11.92]
# |   |   |--- FICO.Range >  729.50
# |   |   |   |--- Amount.Requested <= 14550.00
# |   |   |   |   |--- Open.CREDIT.Lines <= 4.50
# |   |   |   |   |   |--- FICO.Range <= 754.50
# |   |   |   |   |   |   |--- value: [10.64]
# |   |   |   |   |   |--- FICO.Range >  754.50
# |   |   |   |   |   |   |--- value: [8.32]
# |   |   |   |   |--- Open.CREDIT.Lines >  4.50
# |   |   |   |   |   |--- FICO.Range <= 749.50
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 1.50
# |   |   |   |   |   |   |   |--- Monthly.Income <= 7333.33
# |   |   |   |   |   |   |   |   |--- value: [7.40]
# |   |   |   |   |   |   |   |--- Monthly.Income >  7333.33
# |   |   |   |   |   |   |   |   |--- value: [8.31]
# |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  1.50
# |   |   |   |   |   |   |   |--- value: [9.26]
# |   |   |   |   |   |--- FICO.Range >  749.50
# |   |   |   |   |   |   |--- State_TX <= 0.50
# |   |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months <= 1.50
# |   |   |   |   |   |   |   |   |--- value: [6.75]
# |   |   |   |   |   |   |   |--- Inquiries.in.the.Last.6.Months >  1.50
# |   |   |   |   |   |   |   |   |--- value: [7.46]
# |   |   |   |   |   |   |--- State_TX >  0.50
# |   |   |   |   |   |   |   |--- value: [8.20]
# |   |   |   |--- Amount.Requested >  14550.00
# |   |   |   |   |--- FICO.Range <= 764.50
# |   |   |   |   |   |--- Amount.Requested <= 24125.00
# |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 6916.00
# |   |   |   |   |   |   |   |--- value: [10.36]
# |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  6916.00
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 23197.00
# |   |   |   |   |   |   |   |   |--- value: [8.51]
# |   |   |   |   |   |   |   |--- Revolving.CREDIT.Balance >  23197.00
# |   |   |   |   |   |   |   |   |--- value: [10.26]
# |   |   |   |   |   |--- Amount.Requested >  24125.00
# |   |   |   |   |   |   |--- value: [11.03]
# |   |   |   |   |--- FICO.Range >  764.50
# |   |   |   |   |   |--- Revolving.CREDIT.Balance <= 10931.50
# |   |   |   |   |   |   |--- value: [8.91]
# |   |   |   |   |   |--- Revolving.CREDIT.Balance >  10931.50
# |   |   |   |   |   |   |--- value: [7.49]
# |   |--- Loan.Length_60 months >  0.50
# |   |   |--- FICO.Range <= 729.50
# |   |   |   |--- Amount.Requested <= 25662.50
# |   |   |   |   |--- Amount.Requested <= 14500.00
# |   |   |   |   |   |--- Open.CREDIT.Lines <= 8.50
# |   |   |   |   |   |   |--- value: [14.15]
# |   |   |   |   |   |--- Open.CREDIT.Lines >  8.50
# |   |   |   |   |   |   |--- value: [12.41]
# |   |   |   |   |--- Amount.Requested >  14500.00
# |   |   |   |   |   |--- FICO.Range <= 714.50
# |   |   |   |   |   |   |--- value: [16.38]
# |   |   |   |   |   |--- FICO.Range >  714.50
# |   |   |   |   |   |   |--- value: [14.75]
# |   |   |   |--- Amount.Requested >  25662.50
# |   |   |   |   |--- value: [18.51]
# |   |   |--- FICO.Range >  729.50
# |   |   |   |--- FICO.Range <= 754.50
# |   |   |   |   |--- Amount.Requested <= 20187.50
# |   |   |   |   |   |--- Amount.Requested <= 14200.00
# |   |   |   |   |   |   |--- value: [11.28]
# |   |   |   |   |   |--- Amount.Requested >  14200.00
# |   |   |   |   |   |   |--- value: [12.47]
# |   |   |   |   |--- Amount.Requested >  20187.50
# |   |   |   |   |   |--- value: [13.88]
# |   |   |   |--- FICO.Range >  754.50
# |   |   |   |   |--- Amount.Requested <= 23500.00
# |   |   |   |   |   |--- FICO.Range <= 779.50
# |   |   |   |   |   |   |--- value: [9.90]
# |   |   |   |   |   |--- FICO.Range >  779.50
# |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- Amount.Requested >  23500.00
# |   |   |   |   |   |--- value: [11.81]

# %%
x_train.columns
# Out:
# Index(['Loan.Length_36 months', 'Loan.Length_60 months',
#        'Loan.Purpose_debt_consolidation', 'Loan.Purpose_credit_card',
#        'Loan.Purpose_other', 'Loan.Purpose_home_improvement',
#        'Loan.Purpose_major_purchase', 'Loan.Purpose_small_business',
#        'Loan.Purpose___other__', 'Loan.Purpose_car', 'Loan.Purpose_wedding',
#        'Loan.Purpose_medical', 'State_CA', 'State_NY', 'State___other__',
#        'State_FL', 'State_TX', 'State_PA', 'State_IL', 'State_GA', 'State_NJ',
#        'State_VA', 'State_MA', 'State_NC', 'State_OH', 'State_MD', 'State_CO',
#        'State_WA', 'State_CT', 'State_AZ', 'State_MI', 'State_AL', 'State_MN',
#        'State_NV', 'State_MO', 'State_SC', 'State_OR',
#        'Home.Ownership_MORTGAGE', 'Home.Ownership_RENT', 'Home.Ownership_OWN',
#        'Amount.Requested', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#        'Monthly.Income', 'Inquiries.in.the.Last.6.Months',
#        'Debt.To.Income.Ratio', 'FICO.Range', 'Employment.Length'],
#       dtype='object')

# %%
feature_to_plot = ['FICO.Range']  # Replace with actual feature name

# Plot Partial Dependence
fig, ax = plt.subplots(figsize=(10, 6))
PartialDependenceDisplay.from_estimator(dt, x_train, feature_to_plot, ax=ax,kind='average')
plt.show()

# %%
features = [('Amount.Requested', 'FICO.Range')]  # Replace with actual column names

fig, ax = plt.subplots(figsize=(12, 8))
PartialDependenceDisplay.from_estimator(dt, x_train, features, ax=ax, kind="average")
plt.show()

# %% [markdown]
# # Regression Forest

# %%
x_train.shape
# Out:
# (2200, 48)

# %%
# a=[2,3,4,5,6,7,8,9,10]

# %%
# np.random.choice(a,4, replace=True)

# %%
params_rf={
        'n_estimators':[50,100,150,200,250,300], # 6
        'max_features':[2,5,10,15,20,30,40,48],  # 7
        'bootstrap': [True,False], # 2
        'max_depth':[None,5,6,7,8,10,15,20,30,50], # 10
        'min_samples_leaf':[1,2,5,10,15,20], # 6
        'min_samples_split':[2,5,10,15,20] # 5
}

# %%
reg_rf=RandomForestRegressor()

# %%
rs_rf=RandomizedSearchCV(reg_rf,
                        cv=10,
                        param_distributions=params_rf,
                        scoring='neg_mean_absolute_error',
                        n_iter=50,
                        n_jobs=-1,
                        verbose=20)

# %%
rs_rf.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 5, 6, 7, 8, 10, 15,
#                                                       20, 30, 50],
#                                         'max_features': [2, 5, 10, 15, 20, 30,
#                                                          40, 48],
#                                         'min_samples_leaf': [1, 2, 5, 10, 15,
#                                                              20],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [50, 100, 150, 200, 250,
#                                                          300]},
#                    scoring='neg_mean_absolute_error', verbose=20)

# %%
mt.report(rs_rf.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: -1.339545 (std: 0.113715)
# Parameters: {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 30, 'max_depth': 20, 'bootstrap': True}
#
# Model with rank: 2
# Mean validation score: -1.340574 (std: 0.113606)
# Parameters: {'n_estimators': 300, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 30, 'max_depth': None, 'bootstrap': True}
#
# Model with rank: 3
# Mean validation score: -1.353173 (std: 0.115123)
# Parameters: {'n_estimators': 250, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 40, 'max_depth': 10, 'bootstrap': True}
#
# Model with rank: 4
# Mean validation score: -1.368704 (std: 0.112360)
# Parameters: {'n_estimators': 150, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 40, 'max_depth': 7, 'bootstrap': True}
#
# Model with rank: 5
# Mean validation score: -1.369485 (std: 0.123386)
# Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 48, 'max_depth': 7, 'bootstrap': True}

# %%
reg_rf=RandomForestRegressor(**{'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 40, 'max_depth': 8, 'bootstrap': True})

# %%
reg_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=8, max_features=40, min_samples_leaf=5,
#                       min_samples_split=15, n_estimators=200)

# %%
feat_imp_df=pd.DataFrame({'features':x_train.columns,'importance':reg_rf.feature_importances_})

# %%
feat_imp_df.sort_values(by='importance',ascending=False,inplace=True)
feat_imp_df['cum_importance']=feat_imp_df['importance'].cumsum()
feat_imp_df
# Out:
#                            features  importance  cum_importance
# 46                       FICO.Range    0.631638        0.631638
# 1             Loan.Length_60 months    0.149103        0.780741
# 40                 Amount.Requested    0.085771        0.866512
# 0             Loan.Length_36 months    0.059055        0.925567
# 44   Inquiries.in.the.Last.6.Months    0.020114        0.945681
# 41                Open.CREDIT.Lines    0.017365        0.963046
# 45             Debt.To.Income.Ratio    0.009523        0.972568
# 42         Revolving.CREDIT.Balance    0.009408        0.981976
# 43                   Monthly.Income    0.007688        0.989664
# 47                Employment.Length    0.003803        0.993467
# 37          Home.Ownership_MORTGAGE    0.001184        0.994652
# 38              Home.Ownership_RENT    0.000831        0.995483
# 2   Loan.Purpose_debt_consolidation    0.000766        0.996249
# 4                Loan.Purpose_other    0.000707        0.996956
# 16                         State_TX    0.000622        0.997578
# 12                         State_CA    0.000563        0.998141
# 3          Loan.Purpose_credit_card    0.000433        0.998574
# 7       Loan.Purpose_small_business    0.000293        0.998867
# 15                         State_FL    0.000200        0.999067
# 14                  State___other__    0.000187        0.999254
# 5     Loan.Purpose_home_improvement    0.000183        0.999437
# 13                         State_NY    0.000144        0.999581
# 28                         State_CT    0.000096        0.999677
# 26                         State_CO    0.000093        0.999770
# 39               Home.Ownership_OWN    0.000078        0.999848
# 6       Loan.Purpose_major_purchase    0.000065        0.999913
# 9                  Loan.Purpose_car    0.000022        0.999935
# 24                         State_OH    0.000021        0.999955
# 18                         State_IL    0.000017        0.999972
# 27                         State_WA    0.000011        0.999983
# 8            Loan.Purpose___other__    0.000006        0.999989
# 29                         State_AZ    0.000005        0.999994
# 23                         State_NC    0.000004        0.999999
# 17                         State_PA    0.000001        1.000000
# 32                         State_MN    0.000000        1.000000
# 33                         State_NV    0.000000        1.000000
# 34                         State_MO    0.000000        1.000000
# 35                         State_SC    0.000000        1.000000
# 36                         State_OR    0.000000        1.000000
# 31                         State_AL    0.000000        1.000000
# 30                         State_MI    0.000000        1.000000
# 11             Loan.Purpose_medical    0.000000        1.000000
# 25                         State_MD    0.000000        1.000000
# 22                         State_MA    0.000000        1.000000
# 21                         State_VA    0.000000        1.000000
# 20                         State_NJ    0.000000        1.000000
# 19                         State_GA    0.000000        1.000000
# 10             Loan.Purpose_wedding    0.000000        1.000000

# %%
feature_to_plot = ['FICO.Range']  # Replace with actual feature name

# Plot Partial Dependence
fig, ax = plt.subplots(figsize=(10, 6))
PartialDependenceDisplay.from_estimator(reg_rf, x_train, feature_to_plot, ax=ax,kind='average')
plt.show()

# %%
features = [('Amount.Requested', 'FICO.Range')]  # Replace with actual column names

fig, ax = plt.subplots(figsize=(12, 8))
PartialDependenceDisplay.from_estimator(rs_rf, x_train, features, ax=ax, kind="average")
plt.show()

# %%
## Extra Trees & GBM
from sklearn.ensemble import ExtraTreesRegressor,GradientBoostingRegressor, GradientBoostingClassifier
gbmr_params = {
    "n_estimators": [50, 100, 150, 200, 250, 300],
    "max_depth": [3, 5, 10],
    "min_samples_split": [5, 10, 15, 20],
    "learning_rate": [0.01],
    "max_features": [2, 5, 10, 15, 20, 30, 40, 48]
}

# %%
gbmr = GradientBoostingRegressor()

# %%
rs_gbmr=RandomizedSearchCV(gbmr,
                        cv=10,
                        param_distributions=gbmr_params,
                        scoring='neg_mean_absolute_error',
                        n_iter=50,
                        n_jobs=-1,
                        verbose=20)

# %%
rs_gbmr.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# RandomizedSearchCV(cv=10, estimator=GradientBoostingRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.01],
#                                         'max_depth': [3, 5, 10],
#                                         'max_features': [2, 5, 10, 15, 20, 30,
#                                                          40, 48],
#                                         'min_samples_split': [5, 10, 15, 20],
#                                         'n_estimators': [50, 100, 150, 200, 250,
#                                                          300]},
#                    scoring='neg_mean_absolute_error', verbose=20)

# %%
mt.report(rs_gbmr.cv_results_,5)
# Out:
# Model with rank: 1
# Mean validation score: -1.349621 (std: 0.109840)
# Parameters: {'n_estimators': 300, 'min_samples_split': 5, 'max_features': 48, 'max_depth': 5, 'learning_rate': 0.01}
#
# Model with rank: 2
# Mean validation score: -1.369810 (std: 0.107728)
# Parameters: {'n_estimators': 300, 'min_samples_split': 10, 'max_features': 20, 'max_depth': 5, 'learning_rate': 0.01}
#
# Model with rank: 3
# Mean validation score: -1.374607 (std: 0.110749)
# Parameters: {'n_estimators': 300, 'min_samples_split': 15, 'max_features': 30, 'max_depth': 10, 'learning_rate': 0.01}
#
# Model with rank: 4
# Mean validation score: -1.425640 (std: 0.107181)
# Parameters: {'n_estimators': 300, 'min_samples_split': 15, 'max_features': 48, 'max_depth': 10, 'learning_rate': 0.01}
#
# Model with rank: 5
# Mean validation score: -1.430524 (std: 0.111039)
# Parameters: {'n_estimators': 250, 'min_samples_split': 10, 'max_features': 40, 'max_depth': 10, 'learning_rate': 0.01}

# %%
gbmc = GradientBoostingClassifier()

# %%
gbmr_params = {
    "n_estimators": [50, 100, 150, 200, 250, 300],
    "max_depth": [3, 5, 10],
    "min_samples_split": [5, 10, 15, 20],
    "learning_rate": [0.01],
    "max_features": [2, 5, 10, 15, 20, 30, 40, 48]
}

# %%
rs_gbmc=RandomizedSearchCV(gbmc,
                        cv=10,
                        param_distributions=gbmr_params,
                        scoring='neg_mean_absolute_error',
                        n_iter=50,
                        n_jobs=-1,
                        verbose=20)

# %%
rs_gbmc.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 rs_gbmc.fit(x_train,y_train)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1914, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1912 def _run_search(self, evaluate_candidates):
#    1913     """Search n_iter candidates from param_distributions"""
# -> 1914     evaluate_candidates(
#    1915         ParameterSampler(
#    1916             self.param_distributions, self.n_iter, random_state=self.random_state
#    1917         )
#    1918     )
#
# File c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:947, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     940 elif len(out) != n_candidates * n_splits:
#     941     raise ValueError(
#     942         "cv.split and cv.get_n_splits returned "
#     943         "inconsistent results. Expected {} "
#     944         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     945     )
# --> 947 _warn_or_raise_about_fit_failures(out, self.error_score)
#     949 # For callable self.scoring, the return type is only know after
#     950 # calling. If the return type is a dictionary, the error scores
#     951 # can now be inserted with the correct key. The type checking
#     952 # of out will be done in `_insert_error_scores`.
#     953 if callable(self.scoring):
#
# File c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:536, in _warn_or_raise_about_fit_failures(results, error_score)
#     529 if num_failed_fits == num_fits:
#     530     all_fits_failed_message = (
#     531         f"\nAll the {num_fits} fits failed.\n"
#     532         "It is very likely that your model is misconfigured.\n"
#     533         "You can try to debug the error by setting error_score='raise'.\n\n"
#     534         f"Below are more details about the failures:\n{fit_errors_summary}"
#     535     )
# --> 536     raise ValueError(all_fits_failed_message)
#     538 else:
#     539     some_fits_failed_message = (
#     540         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     541         "The score on these train-test partitions for these parameters"
#    (...)
#     545         f"Below are more details about the failures:\n{fit_errors_summary}"
#     546     )
#
# ValueError:
# All the 500 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 500 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py", line 665, in fit
#     y = self._encode_y(y=y, sample_weight=None)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py", line 1500, in _encode_y
#     check_classification_targets(y)
#   File "c:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py", line 221, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
## DT FOR CLASSIFICATION ON BD TRAIN

# %%
## WITH PARTIAL DEPENDENCE PLOT

# %%
## Some ITERATIONS OF RANDOMIZED SEARCH

# %%
## WHAT IS THE ANSWER i DONT WANT
## model agnostic of friedman mse
